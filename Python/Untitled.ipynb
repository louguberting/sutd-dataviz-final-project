# %%
import pandas as pd

rel_fol = "../RebrickableDec082025/"

inventoryparts = pd.read_csv(rel_fol + "inventory_parts.csv", usecols=[0,1,2,3,4])
colors = pd.read_csv(rel_fol + "colors.csv", usecols=[0,1,2,3])
inventories = pd.read_csv(rel_fol + "inventories.csv")



print(inventoryparts)
print(colors)
# Out:
#          inventory_id        part_num  color_id  quantity  is_spare
# 0                   1        48379c04        72         1     False
# 1                   1           48391         0         1     False
# 2                   1           48395         7         1     False
# 3                   1        48864c01        25         1     False
# 4                   1  stickerupn0077      9999         1     False
# ...               ...             ...       ...       ...       ...
# 1434945        308940        3087bc01         4         2     False
# 1434946        308940        7049bc01        15         2     False
# 1434947        308940         737ac01         4         1     False
# 1434948        308940         737ac02         4         1     False
# 1434949        308940        upn0383a         4         4     False
#
# [1434950 rows x 5 columns]
#        id                   name     rgb  is_trans
# 0       0                  Black  05131D     False
# 1      15                  White  FFFFFF     False
# 2      71      Light Bluish Gray  A0A5A9     False
# 3      72       Dark Bluish Gray  6C6E68     False
# 4       4                    Red  C91A09     False
# ..    ...                    ...     ...       ...
# 256  1122        HO Light Yellow  f5fab7     False
# 257  1127      HO Metallic Green  879867     False
# 258  1128  HO Metallic Sand Blue  5f7d8c     False
# 259  1130                HO Rose  d06262     False
# 260  1134            HO Titanium  616161     False
#
# [261 rows x 4 columns]
